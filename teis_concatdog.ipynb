# %%
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## TEIS BDI-3 Analysis
#
# [The Tennessee Early Intervention System (TEIS)](https://www.tn.gov/didd/for-consumers/tennessee-early-intervention-system-teis.html) is a voluntary program that offers therapy and other services to families of infants and young children with developmental delays or disabilities. Services are provided at no cost to families. TEIS is critically important to supporting the development of Tennessee children with disabilities and developmental delays as they prepare for school.
#
# In this project, you are going to be working with data gathered from the Battelle Developmental Inventory, Third Edition (BDI-3) Eligibility Evaluation, an early childhood instrument based on the concept of developmental milestones. The BDI-3 is used by TEIS for determining eligibility and outcomes. This assessment tool has been in use for less than a year now, so the purpose of your work is to analyze the scores to see if there appear to be any weaknesses in this tool in any of the assessed domains or subdomains.
#
# The BDI-3 is divided into 5 domains, each of which has 2 or 3 subdomains. On each domain and subdomain, a child receives several different scores. An example score report is available in the BDI3_ScoreReport.pdf file. See page 3 of this file for a detailed description of each score. Note that the BDI-3 is norm-based, meaning that the scores are generated by the child's performance based on the performance of same-aged peers on the same items.
#
# Some notes about the data:
# * The same instrument is used for determining eligibility and outcomes. The type of evaluation can be determined from the "Program Label" column, which will indicate either an eligibility evaluation, an annual evaluation, or a birthday/milestone or exit evaluation.
# * Some of the rows are duplicated, so be sure to check that in your initial data inspection and cleaning. In addition, some children will have multiple rows in the dataset. A child is evaluated at initial eligibility, annually, and at their 3rd birthday or exit under certain circumstances. The evaluation may be repeated every 4 months (e.g. a child was ineligible and re-referred).
# * There are many records that are missing ID numbers. These records have been given a unique identifier which starts with "SP" so that they can be identified.
# * When reading the data in, you may notice that some of the values in the RDI columns are incorrectly converted to dates. It is likely that this happens whenever the numerator of the fraction is 12 or less.

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# Reading in the Excel file.

# %%
dataset = pd.read_excel(r"C:\Users\mgood\Documents\nss_data_analytics\projects\teis-concat-dog\data\all_evals.xlsx")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23944 entries, 0 to 23943
# Columns: 219 entries, Child ID to Code 10
# dtypes: datetime64[ns](14), float64(79), object(126)
# memory usage: 40.0+ MB

# %% [markdown]
# Dropping duplicates. See below, we go from 23,947 entries in `dataset` 19,500 entries in `dataset_clean`.

# %%
dataset_clean = dataset.drop_duplicates()

# %%
dataset_clean.columns = dataset_clean.columns.str.replace(' ', '_')

# %%
dataset_clean.columns = dataset_clean.columns.str.replace('-', '_')

# %%
dataset_clean.columns = dataset_clean.columns.str.replace('__', '_')

# %% [markdown]
# Dropping cases with no data below.

# %%
check_columns = ['Adaptive_Sum_of_Scaled_Scores', 'Social_Emotional_Sum_of_Scaled_Scores', 'Communication_Sum_of_Scaled_Scores', 'Motor_Sum_of_Scaled_Scores', 'Cognitive_Sum_of_Scaled_Scores']

# %%
dataset_clean.dropna(subset=check_columns, how='all', inplace=True)
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\2153370628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean.dropna(subset=check_columns, how='all', inplace=True)

# %% [markdown]
# Running `.info()` to see we have 19,497 rows.

# %%
dataset_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19497 entries, 0 to 23943
# Columns: 219 entries, Child_ID to Code_10
# dtypes: datetime64[ns](14), float64(79), object(126)
# memory usage: 32.7+ MB

# %% [markdown]
# Checking program size. Probably want to run this later with a completely clean dataset as well.

# %%
dataset_clean.groupby(dataset_clean['Program_Label']).size()
# Out:
# Program_Label
# BDI-3 Annual Evaluation                6904
# BDI-3 Eligibility Evaluation          12390
# BDI-3 Milestone or Exit Evaluation      203
# dtype: int64

# %% [markdown]
# ### concat(dog)'s analysis

# %% [markdown]
# 7. Is there any notable pattern of scoring by region? Note: TEIS contracts with three agencies for evaluations (one per grand region) as follows:
# * East TN, First TN and Southeast
# * Greater Nashville, Upper Cumberland, and South Central
# * Northwest, Southwest, and Memphis Delta

# %% [markdown]
# Checking on count by sex.

# %%
dataset_clean.groupby(dataset_clean['Gender']).size()
# Out:
# Gender
# F     7246
# M    11957
# U      294
# dtype: int64

# %% [markdown]
# There are 87 entries with no sublocation - insignificant enough number that we can drop it later

# %%
dataset_clean[dataset_clean['Location__Sub_Level_1'].isnull()]
# Out:
#       Child_ID Gender Date_of_Birth Location__Sub_Level_1  \
# 117     481875      M    2020-04-22                   NaN
# 159     484037      M    2019-12-03                   NaN
# 237     485687      F    2020-05-17                   NaN
# 318     487138      F    2020-06-28                   NaN
# 581     491452      M    2020-05-22                   NaN
# ...        ...    ...           ...                   ...
# 22548  SP01896      F    2020-09-07                   NaN
# 22556  SP01904      M    2020-06-06                   NaN
# 22582  SP01930      M    2020-06-10                   NaN
# 22592  SP01940      M    2021-09-22                   NaN
# 22656  SP02004      F    2020-12-20                   NaN
#
#                  Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 117    BDI-3 Annual Evaluation                           19.0
# 159    BDI-3 Annual Evaluation                            3.0
# 237    BDI-3 Annual Evaluation                            8.0
# 318    BDI-3 Annual Evaluation                           27.0
# 581    BDI-3 Annual Evaluation                           22.0
# ...                        ...                            ...
# 22548  BDI-3 Annual Evaluation                           28.0
# 22556  BDI-3 Annual Evaluation                           17.0
# 22582  BDI-3 Annual Evaluation                           24.0
# 22592  BDI-3 Annual Evaluation                            9.0
# 22656  BDI-3 Annual Evaluation                            2.0
#
#        Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 117                               97.0                       42
# 159                               49.0                     <0.1
# 237                               64.0                        1
# 318                              121.0                       92
# 581                              106.0                       66
# ...                                ...                      ...
# 22548                            124.0                       95
# 22556                             91.0                       27
# 22582                            112.0                       79
# 22592                             95.0                       37
# 22656                             46.0                     <0.1
#
#       Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_1  \
# 117                             90-104                82/90  ...    NaN
# 159                              45-59  1990-03-01 00:00:00  ...    NaN
# 237                              59-73                18/90  ...    NaN
# 318                            113-127                97/90  ...    NaN
# 581                             99-113                93/90  ...    NaN
# ...                                ...                  ...  ...    ...
# 22548                          116-130                98/90  ...    NaN
# 22556                            85-99                73/90  ...    NaN
# 22582                          104-118                96/90  ...    NaN
# 22592                           86-106                87/90  ...    NaN
# 22656                            42-56                <1/90  ...    NaN
#
#        Code_2 Code_3  Code_4  Code_5 Code_6 Code_7 Code_8 Code_9  Code_10
# 117       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 159       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 237       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 318       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 581       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# ...       ...    ...     ...     ...    ...    ...    ...    ...      ...
# 22548     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 22556     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 22582     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 22592     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 22656     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
#
# [87 rows x 219 columns]

# %% [markdown]
# Grouping locations to three main regions of TN

# %%
location_groups = {
    'East Tennessee': 'East',
    'First Tennessee': 'East',
    'Southeast Tennessee': 'East',
    'Greater Nashville': 'Middle TN',
    'Upper Cumberland': 'Middle TN',
    'South Central': 'Middle TN',
    'Northwest': 'West',
    'Southwest': 'West',
    'Memphis Delta': 'West'
}


dataset_clean['Location_Group'] = dataset_clean['Location__Sub_Level_1'].map(location_groups)


dataset_clean['Location_Group'].fillna('Other', inplace=True)
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\581902080.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['Location_Group'] = dataset_clean['Location__Sub_Level_1'].map(location_groups)
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\581902080.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['Location_Group'].fillna('Other', inplace=True)

# %% [markdown]
# Below I've done some analysis that probably belongs a little later in the notebook :)

# %%
dataset_clean.groupby(dataset_clean['Location__Sub_Level_1']).size()
# Out:
# Location__Sub_Level_1
# East Tennessee         3340
# First Tennessee        1701
# Greater Nashville      3435
# Memphis Delta          2715
# Northwest               955
# South Central          2560
# Southeast Tennessee    1583
# Southwest              1100
# Upper Cumberland       2021
# dtype: int64

# %%
dataset_clean.groupby(dataset_clean['Location_Group']).size()
# Out:
# Location_Group
# East         6624
# Middle TN    8016
# Other          87
# West         4770
# dtype: int64

# %% [markdown]
# Dropping rows with no location data

# %%
location_check = ['Location__Sub_Level_1']

# %%
dataset_clean.dropna(subset=location_check,how='all', inplace=True)
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\2506459002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean.dropna(subset=location_check,how='all', inplace=True)

# %% [markdown]
# After dropping the 87 rows, we have 19,410 entries in `dataset_clean`

# %%
dataset_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19410 entries, 0 to 23943
# Columns: 220 entries, Child_ID to Location_Group
# dtypes: datetime64[ns](14), float64(79), object(127)
# memory usage: 32.7+ MB

# %% [markdown]
# Sean's code: filter for all percentile rank columns to get basic stats by group

# %%
# filter for all PR columns
pr_columns = [col for col in dataset_clean.columns if 'PR' in col]


for col in pr_columns:
    dataset_clean[col] = pd.to_numeric(dataset_clean[col], errors='coerce')


location_grouped_data = dataset_clean.groupby('Location_Group')


pr_stats = {col: location_grouped_data[col].agg(['mean', 'median', 'std', 'count', 'min', 'max']) for col in pr_columns}


for col, stats in pr_stats.items():
    print(f"Statistics for {col}:\n", stats, "\n")
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1757028541.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean[col] = pd.to_numeric(dataset_clean[col], errors='coerce')
# Statistics for Adaptive_Self_Care_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            30.128285    25.0  24.909779   6127  1.0  99.0
# Middle TN       29.599756    25.0  24.994755   7383  1.0  99.0
# West            30.855980    25.0  25.947653   4423  1.0  99.0
#
# Statistics for Adaptive_Personal_Responsibility_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            33.909190    25.0  28.008053   2753  1.0  99.0
# Middle TN       40.886159    37.0  31.399522   3663  1.0  99.0
# West            38.977138    37.0  29.787467   2187  1.0  99.0
#
# Statistics for Social_Emotional_Adult_Interaction_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            53.181037    50.0  25.771027   6518  1.0  99.0
# Middle TN       55.158943    63.0  26.639890   7833  1.0  99.0
# West            59.860987    63.0  26.382297   4719  1.0  99.0
#
# Statistics for Social_Emotional_Peer_Interaction_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            29.705405    25.0  25.709382   2960  1.0  98.0
# Middle TN       34.338731    37.0  27.890727   3767  1.0  99.0
# West            39.332028    37.0  29.026249   2298  1.0  98.0
#
# Statistics for Social_Emotional_Self_Concept_/_Social_Role_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            33.035500    25.0  25.831682   6169  1.0  99.0
# Middle TN       34.679062    25.0  27.098139   7503  1.0  99.0
# West            38.921064    37.0  27.475293   4548  1.0  99.0
#
# Statistics for Communication_Receptive_Communication_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            31.038022    25.0  26.397207   5602  1.0  99.0
# Middle TN       29.191940    25.0  26.918600   6700  1.0  99.0
# West            29.483221    25.0  26.558100   3874  1.0  99.0
#
# Statistics for Communication_Expressive_Communication_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            30.111791    25.0  27.769492   5555  1.0  99.0
# Middle TN       25.968698    16.0  25.954293   6613  1.0  99.0
# West            28.283887    16.0  27.589436   3910  1.0  99.0
#
# Statistics for Motor_Gross_Motor_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            37.012496    37.0  25.687546   6322  1.0  99.0
# Middle TN       39.488694    37.0  26.675194   7651  1.0  99.0
# West            42.441388    37.0  27.500026   4581  1.0  99.0
#
# Statistics for Motor_Fine_Motor_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            50.299039    50.0  28.587277   6454  1.0  99.0
# Middle TN       47.797786    50.0  28.405768   7769  1.0  99.0
# West            52.567013    50.0  29.537676   4626  1.0  99.0
#
# Statistics for Motor_Perceptual_Motor_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            47.301821    50.0  28.544983   2856  1.0  99.0
# Middle TN       45.844813    50.0  29.075676   3557  1.0  99.0
# West            45.404967    50.0  28.149952   2094  1.0  99.0
#
# Statistics for Cognitive_Attention_and_Memory_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            37.419057    37.0  23.178879   6381  1.0  99.0
# Middle TN       34.500197    37.0  23.180833   7627  1.0  99.0
# West            37.901216    37.0  23.089083   4606  1.0  99.0
#
# Statistics for Cognitive_Reasoning_/_Academic_Skills_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            37.870935    37.0  25.164138   2983  1.0  99.0
# Middle TN       37.037565    25.0  27.080272   3647  1.0  99.0
# West            34.968076    25.0  24.195808   2224  1.0  95.0
#
# Statistics for Cognitive_Perception_and_Concepts_PR:
#                       mean  median        std  count  min   max
# Location_Group
# East            34.731553    25.0  26.542925   6180  1.0  99.0
# Middle TN       32.833558    25.0  26.974981   7426  1.0  99.0
# West            32.852407    25.0  26.683890   4404  1.0  99.0

# %% [markdown]
# Compute stats and filter for columns 6-160

# %%
dataset_clean.head()
# Out:
#   Child_ID Gender Date_of_Birth Location__Sub_Level_1  \
# 0    44879      F    2022-09-27             Southwest
# 1    47795      F    2020-12-23     Greater Nashville
# 2    54340      M    2021-06-22       First Tennessee
# 3    54344      F    2022-03-07   Southeast Tennessee
# 4    54515      M    2021-11-04         Memphis Delta
#
#                   Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                             85.0                       16
# 1                             88.0                       21
# 2                             90.0                       25
# 3                            115.0                       84
# 4                             75.0                        5
#
#   Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_2  Code_3  \
# 0                            77-97                39/90  ...    NaN     NaN
# 1                            82-96                79/90  ...    NaN     NaN
# 2                           81-101                77/90  ...    NaN     NaN
# 3                          103-123                99/90  ...    NaN     NaN
# 4                            68-88  1990-09-01 00:00:00  ...    NaN     NaN
#
#   Code_4  Code_5  Code_6 Code_7 Code_8 Code_9 Code_10  Location_Group
# 0    NaN     NaN     NaN    NaN    NaN    NaN     NaN            West
# 1    NaN     NaN     NaN    NaN    NaN    NaN     NaN       Middle TN
# 2    NaN     NaN     NaN    NaN    NaN    NaN     NaN            East
# 3    NaN     NaN     NaN    NaN    NaN    NaN     NaN            East
# 4    NaN     NaN     NaN    NaN    NaN    NaN     NaN            West
#
# [5 rows x 220 columns]

# %% [markdown]
# Creating an `age_at_test_years` and an `age_at_test_days` column

# %%
dataset_clean['age_at_test_years'] = (dataset_clean['Adaptive_Self_Care_Date_of_Testing'].dt.year - dataset_clean['Date_of_Birth'].dt.year)
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1365880338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['age_at_test_years'] = (dataset_clean['Adaptive_Self_Care_Date_of_Testing'].dt.year - dataset_clean['Date_of_Birth'].dt.year)

# %%
dataset_clean['age_at_test_days'] = (dataset_clean['Adaptive_Self_Care_Date_of_Testing'] - dataset_clean['Date_of_Birth'])
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1242800640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['age_at_test_days'] = (dataset_clean['Adaptive_Self_Care_Date_of_Testing'] - dataset_clean['Date_of_Birth'])

# %%
dataset_clean.head()
# Out:
#   Child_ID Gender Date_of_Birth Location__Sub_Level_1  \
# 0    44879      F    2022-09-27             Southwest
# 1    47795      F    2020-12-23     Greater Nashville
# 2    54340      M    2021-06-22       First Tennessee
# 3    54344      F    2022-03-07   Southeast Tennessee
# 4    54515      M    2021-11-04         Memphis Delta
#
#                   Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                             85.0                       16
# 1                             88.0                       21
# 2                             90.0                       25
# 3                            115.0                       84
# 4                             75.0                        5
#
#   Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_4  Code_5  \
# 0                            77-97                39/90  ...    NaN     NaN
# 1                            82-96                79/90  ...    NaN     NaN
# 2                           81-101                77/90  ...    NaN     NaN
# 3                          103-123                99/90  ...    NaN     NaN
# 4                            68-88  1990-09-01 00:00:00  ...    NaN     NaN
#
#   Code_6  Code_7  Code_8 Code_9 Code_10 Location_Group age_at_test_years  \
# 0    NaN     NaN     NaN    NaN     NaN           West               1.0
# 1    NaN     NaN     NaN    NaN     NaN      Middle TN               3.0
# 2    NaN     NaN     NaN    NaN     NaN           East               2.0
# 3    NaN     NaN     NaN    NaN     NaN           East               1.0
# 4    NaN     NaN     NaN    NaN     NaN           West               2.0
#
#    age_at_test_days
# 0          269 days
# 1          818 days
# 2          653 days
# 3          353 days
# 4          477 days
#
# [5 rows x 222 columns]

# %% [markdown]
# Replace missing with NaN

# %%
dataset_clean.replace('', pd.NA, inplace=True)
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1357420498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean.replace('', pd.NA, inplace=True)

# %% [markdown]
# Drop cases with no scores

# %%
check_columns = ['Adaptive_Sum_of_Scaled_Scores', 'Social_Emotional_Sum_of_Scaled_Scores', 'Communication_Sum_of_Scaled_Scores', 'Motor_Sum_of_Scaled_Scores', 'Cognitive_Sum_of_Scaled_Scores']

dataset_clean.dropna(subset=check_columns, how='all', inplace=True)
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\22393909.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean.dropna(subset=check_columns, how='all', inplace=True)

# %% [markdown]
# Create single test-date column

# %%
dataset_clean['test_date'] = dataset_clean['Adaptive_Self_Care_Date_of_Testing']
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\185617121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['test_date'] = dataset_clean['Adaptive_Self_Care_Date_of_Testing']

# %% [markdown]
# Check for missing test dates

# %%
date_nan = 'test_date'
rows_with_nan_test_date = dataset_clean[dataset_clean[date_nan].isna()]

# %% [markdown]
# Assign test date where missing

# %%
dataset_clean.at[13301,'test_date']= pd.to_datetime('2023-08-21')

dataset_clean.at[14721,'test_date'] = pd.to_datetime('2023-05-09')

dataset_clean.at[23271,'test_date']= pd.to_datetime('2023-07-17')

# %%
dataset_clean.head()
# Out:
#   Child_ID Gender Date_of_Birth Location__Sub_Level_1  \
# 0    44879      F    2022-09-27             Southwest
# 1    47795      F    2020-12-23     Greater Nashville
# 2    54340      M    2021-06-22       First Tennessee
# 3    54344      F    2022-03-07   Southeast Tennessee
# 4    54515      M    2021-11-04         Memphis Delta
#
#                   Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                             85.0                       16
# 1                             88.0                       21
# 2                             90.0                       25
# 3                            115.0                       84
# 4                             75.0                        5
#
#   Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_5  Code_6  \
# 0                            77-97                39/90  ...    NaN     NaN
# 1                            82-96                79/90  ...    NaN     NaN
# 2                           81-101                77/90  ...    NaN     NaN
# 3                          103-123                99/90  ...    NaN     NaN
# 4                            68-88  1990-09-01 00:00:00  ...    NaN     NaN
#
#   Code_7  Code_8  Code_9 Code_10 Location_Group age_at_test_years  \
# 0    NaN     NaN     NaN     NaN           West               1.0
# 1    NaN     NaN     NaN     NaN      Middle TN               3.0
# 2    NaN     NaN     NaN     NaN           East               2.0
# 3    NaN     NaN     NaN     NaN           East               1.0
# 4    NaN     NaN     NaN     NaN           West               2.0
#
#   age_at_test_days  test_date
# 0         269 days 2023-06-23
# 1         818 days 2023-03-21
# 2         653 days 2023-04-06
# 3         353 days 2023-02-23
# 4         477 days 2023-02-24
#
# [5 rows x 223 columns]

# %%
dataset_clean['Adaptive_PR'] = dataset_clean['Adaptive_Percentile_Rank']
dataset_clean['Social_Emotional_PR'] = dataset_clean['Social_Emotional_Percentile_Rank']
dataset_clean['Communication_PR'] = dataset_clean['Communication_Percentile_Rank']
dataset_clean['Motor_PR'] = dataset_clean['Motor_Percentile_Rank']
dataset_clean['Cognitive_PR'] = dataset_clean['Cognitive_Percentile_Rank']
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1359340981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['Adaptive_PR'] = dataset_clean['Adaptive_Percentile_Rank']
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1359340981.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['Social_Emotional_PR'] = dataset_clean['Social_Emotional_Percentile_Rank']
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1359340981.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['Communication_PR'] = dataset_clean['Communication_Percentile_Rank']
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1359340981.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['Motor_PR'] = dataset_clean['Motor_Percentile_Rank']
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1359340981.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean['Cognitive_PR'] = dataset_clean['Cognitive_Percentile_Rank']

# %%
percentile_columns = ['Adaptive_Percentile_Rank','Social_Emotional_Percentile_Rank','Communication_Percentile_Rank','Motor_Percentile_Rank','Cognitive_Percentile_Rank']

# %%
dataset_clean[percentile_columns] = dataset_clean[percentile_columns].replace('<0.1', '0.1')
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\3427518723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean[percentile_columns] = dataset_clean[percentile_columns].replace('<0.1', '0.1')

# %% [markdown]
# Isolate to Eligibility Assessment (condition can be updated for other assessment types)

# %%
dataset_clean_eligibility = dataset_clean[dataset_clean["Program_Label"] == 'BDI-3 Eligibility Evaluation']

# %%
dataset_clean_eligibility.head()
# Out:
#   Child_ID Gender Date_of_Birth Location__Sub_Level_1  \
# 0    44879      F    2022-09-27             Southwest
# 1    47795      F    2020-12-23     Greater Nashville
# 2    54340      M    2021-06-22       First Tennessee
# 3    54344      F    2022-03-07   Southeast Tennessee
# 4    54515      M    2021-11-04         Memphis Delta
#
#                   Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                             85.0                       16
# 1                             88.0                       21
# 2                             90.0                       25
# 3                            115.0                       84
# 4                             75.0                        5
#
#   Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_10  \
# 0                            77-97                39/90  ...     NaN
# 1                            82-96                79/90  ...     NaN
# 2                           81-101                77/90  ...     NaN
# 3                          103-123                99/90  ...     NaN
# 4                            68-88  1990-09-01 00:00:00  ...     NaN
#
#    Location_Group age_at_test_years  age_at_test_days  test_date Adaptive_PR  \
# 0            West               1.0          269 days 2023-06-23          16
# 1       Middle TN               3.0          818 days 2023-03-21          21
# 2            East               2.0          653 days 2023-04-06          25
# 3            East               1.0          353 days 2023-02-23          84
# 4            West               2.0          477 days 2023-02-24           5
#
#   Social_Emotional_PR Communication_PR Motor_PR  Cognitive_PR
# 0                  96               27       21            50
# 1                  61               42       55            50
# 2                  27               12       73            13
# 3                  58               21       27            81
# 4                   4                2        4            42
#
# [5 rows x 228 columns]

# %% [markdown]
# These are all object data types, so converting below to numeric.

# %%
dataset_clean_eligibility[percentile_columns] = dataset_clean_eligibility[percentile_columns].apply(pd.to_numeric, errors='coerce')
# Out:
# C:\Users\mgood\AppData\Local\Temp\ipykernel_720\1315868077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_clean_eligibility[percentile_columns] = dataset_clean_eligibility[percentile_columns].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# Group by region for percentile rank

# %%
dataset_clean_eligibility.groupby('Location_Group')[percentile_columns].mean()
# Out:
#                 Adaptive_Percentile_Rank  Social_Emotional_Percentile_Rank  \
# Location_Group
# East                           31.071587                         38.641734
# Middle TN                      31.517061                         40.871186
# West                           33.943533                         49.182707
#
#                 Communication_Percentile_Rank  Motor_Percentile_Rank  \
# Location_Group
# East                                24.798738              43.295641
# Middle TN                           20.430411              42.772248
# West                                23.726475              48.371451
#
#                 Cognitive_Percentile_Rank
# Location_Group
# East                            36.158367
# Middle TN                       32.287722
# West                            35.567066

# %% [markdown]
# Group by sub location for percentile rank

# %%
dataset_clean_eligibility.groupby('Location__Sub_Level_1')[percentile_columns].mean()
# Out:
#                        Adaptive_Percentile_Rank  \
# Location__Sub_Level_1
# East Tennessee                        31.484654
# First Tennessee                       28.577593
# Greater Nashville                     32.691719
# Memphis Delta                         29.713649
# Northwest                             40.317810
# South Central                         30.815045
# Southeast Tennessee                   32.618829
# Southwest                             39.051012
# Upper Cumberland                      30.126320
#
#                        Social_Emotional_Percentile_Rank  \
# Location__Sub_Level_1
# East Tennessee                                37.735285
# First Tennessee                               33.553950
# Greater Nashville                             46.406488
# Memphis Delta                                 46.091690
# Northwest                                     54.963889
# South Central                                 36.141885
# Southeast Tennessee                           45.168683
# Southwest                                     51.991216
# Upper Cumberland                              36.351109
#
#                        Communication_Percentile_Rank  Motor_Percentile_Rank  \
# Location__Sub_Level_1
# East Tennessee                             25.060979              43.270888
# First Tennessee                            25.531733              41.727622
# Greater Nashville                          22.237369              45.240411
# Memphis Delta                              20.675606              45.056192
# Northwest                                  29.370588              52.441667
# South Central                              17.701134              39.607339
# Southeast Tennessee                        23.605664              44.818164
# Southwest                                  26.541835              53.139136
# Upper Cumberland                           20.650639              42.280136
#
#                        Cognitive_Percentile_Rank
# Location__Sub_Level_1
# East Tennessee                         35.096214
# First Tennessee                        35.414241
# Greater Nashville                      36.962353
# Memphis Delta                          33.208090
# Northwest                              40.340033
# South Central                          27.237851
# Southeast Tennessee                    38.909561
# Southwest                              37.409447
# Upper Cumberland                       29.984072

# %% [markdown]
# Create developmental quotient columns list

# %%
dq_columns = ['Adaptive_Developmental_Quotient','Social_Emotional_Developmental_Quotient','Communication_Developmental_Quotient','Motor_Developmental_Quotient','Cognitive_Developmental_Quotient']

# %% [markdown]
# Group by region and age for developmental quotient

# %%
dataset_clean_eligibility.groupby(['age_at_test_years','Location_Group'])[dq_columns].mean()
# can add .to_clipboard() to the end of this statement to copy and paste it elsewhere!
# Out:
#                                   Adaptive_Developmental_Quotient  \
# age_at_test_years Location_Group
# 0.0               East                                  92.456724
#                   Middle TN                             93.703939
#                   West                                  96.505906
# 1.0               East                                  90.383683
#                   Middle TN                             90.068120
#                   West                                  92.563510
# 2.0               East                                  86.398974
#                   Middle TN                             88.426754
#                   West                                  88.131559
# 3.0               East                                  84.196682
#                   Middle TN                             83.170213
#                   West                                  85.598753
#
#                                   Social_Emotional_Developmental_Quotient  \
# age_at_test_years Location_Group
# 0.0               East                                          94.876000
#                   Middle TN                                     96.504447
#                   West                                         101.228346
# 1.0               East                                          97.746968
#                   Middle TN                                     99.683243
#                   West                                         103.412240
# 2.0               East                                          90.648909
#                   Middle TN                                     92.442105
#                   West                                          97.711027
# 3.0               East                                          89.682464
#                   Middle TN                                     89.184659
#                   West                                          92.760915
#
#                                   Communication_Developmental_Quotient  \
# age_at_test_years Location_Group
# 0.0               East                                       98.465863
#                   Middle TN                                  96.403061
#                   West                                      102.449704
# 1.0               East                                       87.033981
#                   Middle TN                                  85.660982
#                   West                                       87.560046
# 2.0               East                                       74.130295
#                   Middle TN                                  72.936842
#                   West                                       73.273764
# 3.0               East                                       73.570071
#                   Middle TN                                  70.910638
#                   West                                       72.207900
#
#                                   Motor_Developmental_Quotient  \
# age_at_test_years Location_Group
# 0.0               East                               97.896000
#                   Middle TN                          98.360510
#                   West                               99.875984
# 1.0               East                               93.670170
#                   Middle TN                          92.699387
#                   West                               96.251732
# 2.0               East                               97.409499
#                   Middle TN                          97.769433
#                   West                              100.392395
# 3.0               East                               95.652482
#                   Middle TN                          92.237892
#                   West                               96.326403
#
#                                   Cognitive_Developmental_Quotient
# age_at_test_years Location_Group
# 0.0               East                                   96.518024
#                   Middle TN                              96.061146
#                   West                                  100.055118
# 1.0               East                                   94.969281
#                   Middle TN                              94.142371
#                   West                                   95.620092
# 2.0               East                                   88.597945
#                   Middle TN                              86.503070
#                   West                                   88.438023
# 3.0               East                                   87.985816
#                   Middle TN                              83.806818
#                   West                                   86.016632

# %% [markdown]
# Group by sub location and age for developmental quotient

# %%
dataset_clean_eligibility.groupby(['age_at_test_years','Location_Group'])[dq_columns].mean()
# Out:
#                                   Adaptive_Developmental_Quotient  \
# age_at_test_years Location_Group
# 0.0               East                                  92.456724
#                   Middle TN                             93.703939
#                   West                                  96.505906
# 1.0               East                                  90.383683
#                   Middle TN                             90.068120
#                   West                                  92.563510
# 2.0               East                                  86.398974
#                   Middle TN                             88.426754
#                   West                                  88.131559
# 3.0               East                                  84.196682
#                   Middle TN                             83.170213
#                   West                                  85.598753
#
#                                   Social_Emotional_Developmental_Quotient  \
# age_at_test_years Location_Group
# 0.0               East                                          94.876000
#                   Middle TN                                     96.504447
#                   West                                         101.228346
# 1.0               East                                          97.746968
#                   Middle TN                                     99.683243
#                   West                                         103.412240
# 2.0               East                                          90.648909
#                   Middle TN                                     92.442105
#                   West                                          97.711027
# 3.0               East                                          89.682464
#                   Middle TN                                     89.184659
#                   West                                          92.760915
#
#                                   Communication_Developmental_Quotient  \
# age_at_test_years Location_Group
# 0.0               East                                       98.465863
#                   Middle TN                                  96.403061
#                   West                                      102.449704
# 1.0               East                                       87.033981
#                   Middle TN                                  85.660982
#                   West                                       87.560046
# 2.0               East                                       74.130295
#                   Middle TN                                  72.936842
#                   West                                       73.273764
# 3.0               East                                       73.570071
#                   Middle TN                                  70.910638
#                   West                                       72.207900
#
#                                   Motor_Developmental_Quotient  \
# age_at_test_years Location_Group
# 0.0               East                               97.896000
#                   Middle TN                          98.360510
#                   West                               99.875984
# 1.0               East                               93.670170
#                   Middle TN                          92.699387
#                   West                               96.251732
# 2.0               East                               97.409499
#                   Middle TN                          97.769433
#                   West                              100.392395
# 3.0               East                               95.652482
#                   Middle TN                          92.237892
#                   West                               96.326403
#
#                                   Cognitive_Developmental_Quotient
# age_at_test_years Location_Group
# 0.0               East                                   96.518024
#                   Middle TN                              96.061146
#                   West                                  100.055118
# 1.0               East                                   94.969281
#                   Middle TN                              94.142371
#                   West                                   95.620092
# 2.0               East                                   88.597945
#                   Middle TN                              86.503070
#                   West                                   88.438023
# 3.0               East                                   87.985816
#                   Middle TN                              83.806818
#                   West                                   86.016632

# %% [markdown]
# Create a dataframe for a clustered bar chart for percentile rank by region

# %%
pr_by_region2_data = {'Region' : ['East','East','East','East','East','Middle TN','Middle TN','Middle TN','Middle TN','Middle TN','Other','Other','Other','Other','Other','West','West','West','West','West'],
                      'Domain' : ['Adaptive','Social Emotional','Communication','Motor','Cognitive','Adaptive','Social Emotional','Communication','Motor','Cognitive','Adaptive','Social Emotional','Communication','Motor','Cognitive','Adaptive','Social Emotional','Communication','Motor','Cognitive'],
                      'Percentile Rank' : [31.071587,38.641734,24.798738,43.295641,36.158367,31.517061,40.871186,20.430411,42.772248,32.287722,46.166667,44.183333,8.025000,27.750000,33.550000,33.943533,49.182707,23.726475,48.371451,35.567066]}
pr_by_region2 = pd.DataFrame(pr_by_region2_data)

# %%
pr_by_region2
# Out:
#        Region            Domain  Percentile Rank
# 0        East          Adaptive        31.071587
# 1        East  Social Emotional        38.641734
# 2        East     Communication        24.798738
# 3        East             Motor        43.295641
# 4        East         Cognitive        36.158367
# 5   Middle TN          Adaptive        31.517061
# 6   Middle TN  Social Emotional        40.871186
# 7   Middle TN     Communication        20.430411
# 8   Middle TN             Motor        42.772248
# 9   Middle TN         Cognitive        32.287722
# 10      Other          Adaptive        46.166667
# 11      Other  Social Emotional        44.183333
# 12      Other     Communication         8.025000
# 13      Other             Motor        27.750000
# 14      Other         Cognitive        33.550000
# 15       West          Adaptive        33.943533
# 16       West  Social Emotional        49.182707
# 17       West     Communication        23.726475
# 18       West             Motor        48.371451
# 19       West         Cognitive        35.567066

# %%
sns.barplot(hue='Domain',y='Percentile Rank',x='Region',data=pr_by_region2)
plt.title("Average Percentile Rank by Region")
# Out:
# Text(0.5, 1.0, 'Average Percentile Rank by Region')

# %%
dataset_clean.groupby(dataset_clean['Location__Sub_Level_1']).size()
# Out:
# Location__Sub_Level_1
# East Tennessee         3340
# First Tennessee        1701
# Greater Nashville      3435
# Memphis Delta          2715
# Northwest               955
# South Central          2560
# Southeast Tennessee    1583
# Southwest              1100
# Upper Cumberland       2021
# dtype: int64

# %% [markdown]
# Using Rushi's code from earlier as a reference to create a new df for the locations by evaluation count for another visual.

# %%
# pr_by_region2_data = {'Region' : ['East','East','East','East','East','Middle TN','Middle TN','Middle TN','Middle TN','Middle TN','Other','Other','Other','Other','Other','West','West','West','West','West'],
#                       'Domain' : ['Adaptive','Social Emotional','Communication','Motor','Cognitive','Adaptive','Social Emotional','Communication','Motor','Cognitive','Adaptive','Social Emotional','Communication','Motor','Cognitive','Adaptive','Social Emotional','Communication','Motor','Cognitive'],
#                       'Percentile Rank' : [31.071587,38.641734,24.798738,43.295641,36.158367,31.517061,40.871186,20.430411,42.772248,32.287722,46.166667,44.183333,8.025000,27.750000,33.550000,33.943533,49.182707,23.726475,48.371451,35.567066]}
# pr_by_region2 = pd.DataFrame(pr_by_region2_data)

# %%
location_count_analysis = {'Location': ['East Tennessee', 'First Tennessee', 'Southeast Tennessee','Greater Nashville', 'South Central','Upper Cumberland','Memphis Delta','Southwest','Northwest'],
                           'Region' : ['East', 'East', 'East','Middle', 'Middle','Middle', 'West', 'West','West'],
                           'Evaluation Count': [3340, 1701, 1583, 3435, 2560, 2021, 2715, 1100, 955]}
location_count_analysis_df = pd.DataFrame(location_count_analysis)

# %%
location_count_analysis_df
# Out:
#               Location  Region  Evaluation Count
# 0       East Tennessee    East              3340
# 1      First Tennessee    East              1701
# 2  Southeast Tennessee    East              1583
# 3    Greater Nashville  Middle              3435
# 4        South Central  Middle              2560
# 5     Upper Cumberland  Middle              2021
# 6        Memphis Delta    West              2715
# 7            Southwest    West              1100
# 8            Northwest    West               955

# %%
region_dict = {
    'Northwest' : '#72B99C',
    'Southwest' : '#978d87',
    'Memphis Delta' : '#a2c7cd',
    'Greater Nashville' : '#EE8783',
    'Upper Cumberland' : '#b7bfa',
    'South Central' : '#cbc56b',
    'East Tennessee' : '#7C99BD',
    'First Tennessee' : '#f9c167',
    'Southeast Tennessee' : '#bf8fa3'
}

# %%
ax = sns.barplot(hue='Location',y='Evaluation Count',x='Region',data=location_count_analysis_df)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
ax.set(xlabel=None)
ax.set(ylabel=None)
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
palette = sns.color_palette(region_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\mgood\anaconda3\Lib\site-packages\seaborn\palettes.py:251, in color_palette(palette, n_colors, desat, as_cmap)
#     250     palette = map(mpl.colors.colorConverter.to_rgb, palette)
# --> 251     palette = _ColorPalette(palette)
#     252 except ValueError:
#
# File c:\Users\mgood\anaconda3\Lib\site-packages\matplotlib\colors.py:496, in to_rgb(c)
#     495 """Convert *c* to an RGB color, silently dropping the alpha channel."""
# --> 496 return to_rgba(c)[:3]
#
# File c:\Users\mgood\anaconda3\Lib\site-packages\matplotlib\colors.py:299, in to_rgba(c, alpha)
#     298 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 299     rgba = _to_rgba_no_colorcycle(c, alpha)
#     300     try:
#
# File c:\Users\mgood\anaconda3\Lib\site-packages\matplotlib\colors.py:374, in _to_rgba_no_colorcycle(c, alpha)
#     373         return c, c, c, alpha if alpha is not None else 1.
# --> 374     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     375 # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: 'Northwest'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[140], line 7
#       5 custom_params = {"axes.spines.right": False, "axes.spines.top": False}
#       6 sns.set_theme(style="ticks", rc=custom_params)
# ----> 7 palette = sns.color_palette(region_dict)
#
# File c:\Users\mgood\anaconda3\Lib\site-packages\seaborn\palettes.py:253, in color_palette(palette, n_colors, desat, as_cmap)
#     251         palette = _ColorPalette(palette)
#     252     except ValueError:
# --> 253         raise ValueError(f"Could not generate a palette for {palette}")
#     255 return palette
#
# ValueError: Could not generate a palette for <map object at 0x00000172C47B09D0>

# %%
location_count_analysis2 = {'Location': ['East Tennessee', 'First Tennessee', 'Southeast Tennessee','Greater Nashville', 'South Central','Upper Cumberland','Memphis Delta','Southwest','Northwest'],
                           'Evaluation Count': [3340, 1701, 1583, 3435, 2560, 2021, 2715, 1100, 955]}
location_count_analysis2_df = pd.DataFrame(location_count_analysis2)

# %%
ax = sns.barplot(x='Evaluation Count',y='Location',data=location_count_analysis2_df)
ax.set(xlabel=None)
ax.set(ylabel=None)
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
palette = sns.color_palette(region_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\mgood\anaconda3\Lib\site-packages\seaborn\palettes.py:251, in color_palette(palette, n_colors, desat, as_cmap)
#     250     palette = map(mpl.colors.colorConverter.to_rgb, palette)
# --> 251     palette = _ColorPalette(palette)
#     252 except ValueError:
#
# File c:\Users\mgood\anaconda3\Lib\site-packages\matplotlib\colors.py:496, in to_rgb(c)
#     495 """Convert *c* to an RGB color, silently dropping the alpha channel."""
# --> 496 return to_rgba(c)[:3]
#
# File c:\Users\mgood\anaconda3\Lib\site-packages\matplotlib\colors.py:299, in to_rgba(c, alpha)
#     298 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 299     rgba = _to_rgba_no_colorcycle(c, alpha)
#     300     try:
#
# File c:\Users\mgood\anaconda3\Lib\site-packages\matplotlib\colors.py:374, in _to_rgba_no_colorcycle(c, alpha)
#     373         return c, c, c, alpha if alpha is not None else 1.
# --> 374     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     375 # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: 'Northwest'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 6
#       4 custom_params = {"axes.spines.right": False, "axes.spines.top": False}
#       5 sns.set_theme(style="ticks", rc=custom_params)
# ----> 6 palette = sns.color_palette(region_dict)
#
# File c:\Users\mgood\anaconda3\Lib\site-packages\seaborn\palettes.py:253, in color_palette(palette, n_colors, desat, as_cmap)
#     251         palette = _ColorPalette(palette)
#     252     except ValueError:
# --> 253         raise ValueError(f"Could not generate a palette for {palette}")
#     255 return palette
#
# ValueError: Could not generate a palette for <map object at 0x00000172C47DFA60>

# %%
 plt.savefig('Ax', dpi=300)

# %% [markdown]
# Adding visuals for age and gender distribution by location

# %%
dataset_clean.head()
# Out:
#   Child_ID Gender Date_of_Birth Location__Sub_Level_1  \
# 0    44879      F    2022-09-27             Southwest
# 1    47795      F    2020-12-23     Greater Nashville
# 2    54340      M    2021-06-22       First Tennessee
# 3    54344      F    2022-03-07   Southeast Tennessee
# 4    54515      M    2021-11-04         Memphis Delta
#
#                   Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                             85.0                       16
# 1                             88.0                       21
# 2                             90.0                       25
# 3                            115.0                       84
# 4                             75.0                        5
#
#   Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_10  \
# 0                            77-97                39/90  ...     NaN
# 1                            82-96                79/90  ...     NaN
# 2                           81-101                77/90  ...     NaN
# 3                          103-123                99/90  ...     NaN
# 4                            68-88  1990-09-01 00:00:00  ...     NaN
#
#    Location_Group age_at_test_years  age_at_test_days  test_date Adaptive_PR  \
# 0            West               1.0          269 days 2023-06-23          16
# 1       Middle TN               3.0          818 days 2023-03-21          21
# 2            East               2.0          653 days 2023-04-06          25
# 3            East               1.0          353 days 2023-02-23          84
# 4            West               2.0          477 days 2023-02-24           5
#
#   Social_Emotional_PR Communication_PR Motor_PR  Cognitive_PR
# 0                  96               27       21            50
# 1                  61               42       55            50
# 2                  27               12       73            13
# 3                  58               21       27            81
# 4                   4                2        4            42
#
# [5 rows x 228 columns]

# %%
# age_by_region = dataset_clean.groupby('Location_Group')['age_at_test_years'].count()
# age_by_region.head()

age_by_location = dataset_clean.groupby('Location__Sub_Level_1') \
       .agg({'age_at_test_years':'mean'}) \
        .rename(columns={'Location__Sub_Level_1':'Location','age_at_test_years':'Average_Age'}) \
       .reset_index()

# dataset_clean.groupby(['age_at_test_years','Location_Group']).mean()
# can add .to_clipboard() to the end of this statement to copy and paste it elsewhere!

# %%
age_by_location
# Out:
#   Location__Sub_Level_1  Average_Age
# 0        East Tennessee     1.826647
# 1       First Tennessee     1.742941
# 2     Greater Nashville     1.853857
# 3         Memphis Delta     1.901289
# 4             Northwest     1.730890
# 5         South Central     1.885893
# 6   Southeast Tennessee     1.801517
# 7             Southwest     1.780909
# 8      Upper Cumberland     1.898070

# %%
avg_age_analysis = {'Location': ['East Tennessee', 'First Tennessee', 'Southeast Tennessee','Greater Nashville', 'South Central','Upper Cumberland','Memphis Delta','Southwest','Northwest'],
                           'Region' : ['East', 'East', 'East','Middle', 'Middle','Middle', 'West', 'West','West'],
                           'Average Age': [1.83, 1.74, 1.80, 1.85, 1.89, 1.90, 1.90, 1.78, 1.73]}
avg_age_analysis_df = pd.DataFrame(avg_age_analysis)

# %%
ax1 = sns.barplot(hue= 'Location', y='Average Age',x='Region',data=avg_age_analysis_df)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
ax1.set(xlabel=None)
ax1.set(ylabel='Average Age (Years)')
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
# palette = sns.color_palette(region_dict)

# %%
avg_age_analysis2 = {'Location': ['East Tennessee', 'First Tennessee', 'Southeast Tennessee','Greater Nashville', 'South Central','Upper Cumberland','Memphis Delta','Southwest','Northwest'],
                           'Average Age': [1.83, 1.74, 1.80, 1.85, 1.89, 1.90, 1.90, 1.78, 1.73]}
avg_age_analysis2_df = pd.DataFrame(avg_age_analysis2)

# %%
ax1 = sns.barplot(x='Average Age',y='Location',data=avg_age_analysis2_df)
ax1.set(ylabel=None)
ax1.set(xlabel='Average Age (Years)')
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
# palette = sns.color_palette(region_dict)

# %%
# dataset_clean_eligibility = dataset_clean[dataset_clean["Program_Label"] == 'BDI-3 Eligibility Evaluation']

# %%
age_by_location = dataset_clean.groupby('Location__Sub_Level_1')['age_at_test_years'].count()
age_by_location.head()
# Out:
# Location__Sub_Level_1
# East Tennessee       3340
# First Tennessee      1700
# Greater Nashville    3435
# Memphis Delta        2715
# Northwest             955
# Name: age_at_test_years, dtype: int64

# %%
location_count_analysis = {'Location': ['East Tennessee', 'First Tennessee', 'Southeast Tennessee','Greater Nashville', 'South Central','Upper Cumberland','Memphis Delta','Southwest','Northwest'],
                           'Region' : ['East', 'East', 'East','Middle', 'Middle','Middle', 'West', 'West','West'],
                           'Evaluation Count': [3340, 1701, 1583, 3435, 2560, 2021, 2715, 1100, 955]}
location_count_analysis_df = pd.DataFrame(location_count_analysis)

# %% [markdown]
# STOP HERE UNTIL 7 IS ANSWERED

# %% [markdown]
# ************

# %% [markdown]
# ADDITIONAL QUESTIONS BELOW

# %% [markdown]
# Project Objectives:
# 1. In which domains (and sub-domains) are children performing highest and lowest?

# %% [markdown]
# * Make an age column
# * Percentile rank might be a good measure since it's for their age group.

# %% [markdown]
# 2. What is the pattern of children's scores? Do individual children tend to perform similarly across all domains or are there differences from domain to domain? Are these patterns similar for all children?

# %%
sns.histplot(dataset,
                 x = dataset_clean['Adaptive_Developmental_Quotient'])
# Out:
# <Axes: xlabel='Adaptive_Developmental_Quotient', ylabel='Count'>

# %%
sns.histplot(dataset,
                 x = dataset_clean['Motor_Developmental_Quotient'])
# Out:
# <Axes: xlabel='Motor_Developmental_Quotient', ylabel='Count'>

# %%
sns.histplot(dataset,
                 x = dataset_clean['Cognitive_Developmental_Quotient'])
# Out:
# <Axes: xlabel='Cognitive_Developmental_Quotient', ylabel='Count'>

# %%
sns.histplot(dataset,
                 x = dataset_clean['Communication_Developmental_Quotient'])
# Out:
# <Axes: xlabel='Communication_Developmental_Quotient', ylabel='Count'>

# %%
sns.histplot(dataset,
                 x = dataset_clean['Social_Emotional_Developmental_Quotient'])
# Out:
# <Axes: xlabel='Social_Emotional_Developmental_Quotient', ylabel='Count'>

# %%
sns.histplot(dataset,
                 x = dataset_clean['BDI_3_Total_Developmental_Quotient'])
# Out:
# <Axes: xlabel='BDI_3_Total_Developmental_Quotient', ylabel='Count'>

# %% [markdown]
# 3. Is there a pattern of significant differences in children's scores in the sub-domains within a domain? For example, a gap between a child's expressive (talking) and receptive (understanding) language scores may indicate that additional evaluation is needed for that child's eligibility. A gap between these sub-domains for all or most children may indicate the BDI-3 tool may lack sensitivity in the language domain.

# %% [markdown]
# 4. Does the child's age seem to impact their scoring?

# %% [markdown]
# 5. Eligibility is currently based on domains. A child would be considered eligible based on a 40% delay in one area or 25% delay in two areas, as determined by Development Quotient (DQ) scores. A DQ of 70 or less indicates a 40% delay, and a DQ between 71 and 78 indicates a 25% delay. If TEIS added an option for eligibility based on the total score on the BDI-3 total score (DQ score of 70 or less), are there any children who would have qualified that did not qualify based on the current method?

# %% [markdown]
# 6. Is there any difference in scoring noted based on evaluation type?

# %% [markdown]
# 8. Is there any notable pattern of scoring by evaluator?

# %% [markdown]
# Stretch Goal:
# * Investigate the records that are missing ID values. Have they gotten better or worse over time? Are there repeat offenders?
# * As noted above, this evaluation may be repeated every 4 months. How often did it occur that a child was assessed multiple times in a time period of less than 120 days. Has this gotten better or worse over time?
#
#
# (question: does "better or worse" mean that more repeat testing is better?)
